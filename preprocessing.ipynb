# %% [markdown]
# Before running the file Upload all your data set on your goole drive in a zip format

# %%
#Mount our google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path ="/content/drive/MyDrive/dfdc_train_part_08/dfdc_train_part_8"

# %%
#To get the average frame count
import json
import glob
import numpy as np
import cv2
import copy
#change the path accordingly
video_files =  glob.glob('/content/drive/MyDrive/dfdc_train_part_08/dfdc_train_part_8/*.mp4')
video_files1 =  glob.glob('/content/drive/MyDrive/dataset/Fake_videos/*.mp4')
video_files2 =  glob.glob('/content/drive/MyDrive/dataset/Real_videos/*.mp4')
video_files3 =  glob.glob('/content/drive/MyDrive/archive/Celeb-real/*.mp4')
video_files4 =  glob.glob('/content/drive/MyDrive/archive/Celeb-synthesis/*.mp4')
video_files += video_files1
video_files += video_files2
video_files += video_files3
video_files += video_files4
frame_count = []
for video_file in video_files:
  cap = cv2.VideoCapture(video_file)
  if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<150):
    video_files.remove(video_file)
    continue
  frame_count.append(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print("frames" , frame_count)
print("Total number of videos: " , len(frame_count))
print('Average frame per video:',np.mean(frame_count))
# Out:
# frames [301, 299, 299, 301, 301, 300, 301, 299, 301, 300, 299, 300, 299, 299, 300, 300, 300, 300, 301, 300, 299, 300, 300, 300, 301, 300, 300, 300, 299, 301, 300, 301, 301, 300, 300, 301, 300, 300, 301, 300, 301, 300, 300, 300, 299, 300, 300, 300, 299, 300, 300, 300, 300, 300, 300, 300, 300, 301, 299, 301, 300, 301, 301, 300, 299, 300, 299, 300, 300, 301, 300, 300, 300, 300, 301, 299, 301, 300, 299, 300, 300, 301, 299, 299, 299, 301, 299, 300, 299, 300, 300, 301, 299, 300, 299, 301, 300, 300, 301, 300, 301, 301, 300, 301, 300, 300, 299, 300, 300, 299, 300, 301, 299, 300, 300, 301, 299, 299, 300, 300, 300, 300, 300, 300, 301, 300, 300, 300, 299, 301, 301, 301, 300, 300, 300, 299, 300, 301, 299, 300, 300, 300, 299, 299, 300, 299, 300, 300, 300, 301, 300, 300, 299, 301, 300, 300, 301, 301, 300, 299, 300, 299, 300, 300, 299, 300, 300, 300, 301, 300, 300, 300, 299, 299, 301, 299, 300, 300, 300, 301, 299, 301, 301, 300, 299, 300, 299, 301, 301, 301, 301, 300, 299, 301, 299, 301, 300, 299, 
# ...

# %%
# to extract frame
def frame_extract(path):
  vidObj = cv2.VideoCapture(path)
  success = 1
  while success:
      success, image = vidObj.read()
      if success:
          yield image
# !pip3 install face_recognition
# !mkdir '/content/drive/My Drive/Face_only_data'
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
from tqdm.autonotebook import tqdm
# process the frames
def create_face_videos(path_list,out_dir):
  already_present_count =  glob.glob(out_dir+'*.mp4')
  print("No of videos already present " , len(already_present_count))
  for path in tqdm(path_list):
    out_path = os.path.join(out_dir,path.split('/')[-1])
    file_exists = glob.glob(out_path)
    if(len(file_exists) != 0):
      print("File Already exists: " , out_path)
      continue
    frames = []
    flag = 0
    face_all = []
    frames1 = []
    out = cv2.VideoWriter(out_path,cv2.VideoWriter_fourcc('M','J','P','G'), 30, (112,112))
    for idx,frame in enumerate(frame_extract(path)):
      #if(idx % 3 == 0):
      if(idx <= 150):
        frames.append(frame)
        if(len(frames) == 4):
          faces = face_recognition.batch_face_locations(frames)
          for i,face in enumerate(faces):
            if(len(face) != 0):
              top,right,bottom,left = face[0]
            try:
              out.write(cv2.resize(frames[i][top:bottom,left:right,:],(112,112)))
            except:
              pass
          frames = []
    try:
      del top,right,bottom,left
    except:
      pass
    out.release()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566166 sha256=cfc637db396e27ed06b3e7a015671983a3c3446eb8120b6dbd11fd677d40b18e
#   Stored in directory: /root/.cache/pip/wheels/8f/47/c8/f44c5aebb7507f7c8a2c0bd23151d732d0f0bd6884ad4ac635
# Successfully built face-recognition-models
# ...
# mkdir: cannot create directory ‘/content/drive/My Drive/Face_only_data’: File exists
# /tmp/ipykernel_2006/1292837424.py:21: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
create_face_videos(video_files,'/content/drive/My Drive/Face_only_data/')
# Out:
# No of videos already present  600
#   0%|          | 0/6937 [00:00<?, ?it/s]
# File Already exists:  /content/drive/My Drive/Face_only_data/hnqocyfmyk.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/hlgicjaytp.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/hombhxahfr.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/hlbrbkvyhr.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/hmrthkkvam.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/hphrzocvcs.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/hqmuwcrdoz.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/hqdnnmxlwi.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/hsijefjiop.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/hsverfwbdy.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/humbrhuzib.mp4
# ...
